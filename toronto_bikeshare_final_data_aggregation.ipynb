# %% [markdown]
# # In this notebook I bring together the yearly bikeshare data into a single DataFrame containing data from 2017-2020.

# %% [markdown]
# I'll start by importing our essential DataFrame manipulation packages...

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# Let's bring in our bikeshare data csvs...

# %%
df_2017 = pd.read_csv('Desktop/to_bikeshare_project/df_2017.csv')
df_2018 = pd.read_csv('Desktop/to_bikeshare_project/df_2018.csv')
df_2019 = pd.read_csv('Desktop/to_bikeshare_project/df_2019.csv')
df_2020 = pd.read_csv('Desktop/to_bikeshare_project/df_2020.csv')

# %% [markdown]
# I'll start by taking a look at the 2017 DataFrame.

# %%
df_2017.head(5)
# Out:
#    Unnamed: 0  trip_id      trip_start_time       trip_stop_time  \
# 0           0   712382  2017-01-01 00:00:00  2017-01-01 00:03:00
# 1           1   712383  2017-01-01 00:00:00  2017-01-01 00:05:00
# 2           2   712384  2017-01-01 00:05:00  2017-01-01 00:29:00
# 3           3   712385  2017-01-01 00:07:00  2017-01-01 00:21:00
# 4           4   712386  2017-01-01 00:08:00  2017-01-01 00:12:00
#
#    trip_duration_seconds                  from_station_name  \
# 0                    223  Wellesley St E / Yonge St Green P
# 1                    279           Kendal Ave / Bernard Ave
# 2                   1394       Parliament St / Aberdeen Ave
# 3                    826                 College Park South
# 4                    279              McGill St / Church St
#
#                  to_station_name user_type  start_date start_time   stop_date  \
# 0           Church St  / Wood St    Member  01/01/2017      00:00  01/01/2017
# 1        Bathurst Subway Station    Member  01/01/2017      00:00  01/01/2017
# 2      College St W / Markham St    Member  01/01/2017      00:05  01/01/2017
# 3        King St W / Spadina Ave    Member  01/01/2017      00:07  01/01/2017
# 4  University Ave / Gerrard St W    Member  01/01/2017      00:08  01/01/2017
#
#   stop_time
# 0     00:03
# 1     00:05
# 2     00:29
# 3     00:21
# 4     00:12

# %% [markdown]
# We can definitely drop trip_id which will be unnecessary for analysis, as well as the extra index column.

# %%
df_2017.drop(['trip_id', 'Unnamed: 0'], axis=1, inplace=True)

# %% [markdown]
# Let's look at the unique values in the user_type column as I want to ensure that these are formatted the same across the DataFrames before joining them.

# %%
df_2017['user_type'].unique()
# Out:
# array(['Member', 'Casual'], dtype=object)

# %%
df_2017.head()
# Out:
#        trip_start_time       trip_stop_time  trip_duration_seconds  \
# 0  2017-01-01 00:00:00  2017-01-01 00:03:00                    223
# 1  2017-01-01 00:00:00  2017-01-01 00:05:00                    279
# 2  2017-01-01 00:05:00  2017-01-01 00:29:00                   1394
# 3  2017-01-01 00:07:00  2017-01-01 00:21:00                    826
# 4  2017-01-01 00:08:00  2017-01-01 00:12:00                    279
#
#                    from_station_name                to_station_name user_type  \
# 0  Wellesley St E / Yonge St Green P           Church St  / Wood St    Member
# 1           Kendal Ave / Bernard Ave        Bathurst Subway Station    Member
# 2       Parliament St / Aberdeen Ave      College St W / Markham St    Member
# 3                 College Park South        King St W / Spadina Ave    Member
# 4              McGill St / Church St  University Ave / Gerrard St W    Member
#
#    start_date start_time   stop_date stop_time
# 0  01/01/2017      00:00  01/01/2017     00:03
# 1  01/01/2017      00:00  01/01/2017     00:05
# 2  01/01/2017      00:05  01/01/2017     00:29
# 3  01/01/2017      00:07  01/01/2017     00:21
# 4  01/01/2017      00:08  01/01/2017     00:12

# %% [markdown]
# Looks good. Now let's look at the 2018 DataFrame.

# %%
df_2018.head(5)
# Out:
#    Unnamed: 0  trip_id  trip_duration_seconds  from_station_id  \
# 0           0  2383648                    393             7018
# 1           1  2383649                    625             7184
# 2           2  2383650                    233             7235
# 3           3  2383651                   1138             7202
# 4           4  2383652                    703             7004
#
#        trip_start_time                        from_station_name  \
# 0  2018-01-01 00:47:00                   Bremner Blvd / Rees St
# 1  2018-01-01 00:52:00               Ossington Ave / College St
# 2  2018-01-01 00:55:00  Bay St / College St (West Side) - SMART
# 3  2018-01-01 00:57:00         Queen St W / York St (City Hall)
# 4  2018-01-01 01:00:00                  University Ave / Elm St
#
#         trip_stop_time  to_station_id               to_station_name  \
# 0  2018-01-01 00:54:00           7176  Bathurst St / Fort York Blvd
# 1  2018-01-01 01:03:00           7191    Central Tech  (Harbord St)
# 2  2018-01-01 00:59:00           7021            Bay St / Albert St
# 3  2018-01-01 01:16:00           7020       Phoebe St / Spadina Ave
# 4  2018-01-01 01:12:00           7060   Princess St / Adelaide St E
#
#        user_type  start_date start_time   stop_date stop_time
# 0  Annual Member  01/01/2018      00:47  01/01/2018     00:54
# 1  Annual Member  01/01/2018      00:52  01/01/2018     01:03
# 2  Annual Member  01/01/2018      00:55  01/01/2018     00:59
# 3  Annual Member  01/01/2018      00:57  01/01/2018     01:16
# 4  Annual Member  01/01/2018      01:00  01/01/2018     01:12

# %% [markdown]
# We can drop the extra index, trip_id, and the station_id numbers since we already have the station names.

# %%
df_2018.drop(['Unnamed: 0', 'trip_id', 'from_station_id', 'to_station_id'], axis=1, inplace=True )

# %% [markdown]
# Let's look at the unique values in user_type.

# %%
df_2018['user_type'].unique()
# Out:
# array(['Annual Member', 'Casual Member'], dtype=object)

# %% [markdown]
# We can see that the names have been altered slightly. I'll modify them so they match the the 2017 DataFrame.

# %%
df_2018['user_type'] = df_2018['user_type'].replace({'Annual Member': 'Member', 'Casual Member': 'Casual'})

# %%
df_2018.head(5)
# Out:
#    trip_duration_seconds      trip_start_time  \
# 0                    393  2018-01-01 00:47:00
# 1                    625  2018-01-01 00:52:00
# 2                    233  2018-01-01 00:55:00
# 3                   1138  2018-01-01 00:57:00
# 4                    703  2018-01-01 01:00:00
#
#                          from_station_name       trip_stop_time  \
# 0                   Bremner Blvd / Rees St  2018-01-01 00:54:00
# 1               Ossington Ave / College St  2018-01-01 01:03:00
# 2  Bay St / College St (West Side) - SMART  2018-01-01 00:59:00
# 3         Queen St W / York St (City Hall)  2018-01-01 01:16:00
# 4                  University Ave / Elm St  2018-01-01 01:12:00
#
#                 to_station_name user_type  start_date start_time   stop_date  \
# 0  Bathurst St / Fort York Blvd    Member  01/01/2018      00:47  01/01/2018
# 1    Central Tech  (Harbord St)    Member  01/01/2018      00:52  01/01/2018
# 2            Bay St / Albert St    Member  01/01/2018      00:55  01/01/2018
# 3       Phoebe St / Spadina Ave    Member  01/01/2018      00:57  01/01/2018
# 4   Princess St / Adelaide St E    Member  01/01/2018      01:00  01/01/2018
#
#   stop_time
# 0     00:54
# 1     01:03
# 2     00:59
# 3     01:16
# 4     01:12

# %% [markdown]
# Looks good! Now let's move onto the 2019 data...

# %%
df_2019.head(5)
# Out:
#    Unnamed: 0  Trip Id  Trip  Duration  Start Station Id           Start Time  \
# 0           0  4581278          1547.0              7021  2019-01-01 00:08:00
# 1           1  4581279          1112.0              7160  2019-01-01 00:10:00
# 2           2  4581280           589.0              7055  2019-01-01 00:15:00
# 3           3  4581281           259.0              7012  2019-01-01 00:16:00
# 4           4  4581282           281.0              7041  2019-01-01 00:19:00
#
#                         Start Station Name  End Station Id  \
# 0                       Bay St / Albert St          7233.0
# 1                 King St W / Tecumseth St          7051.0
# 2                   Jarvis St / Carlton St          7013.0
# 3  Elizabeth St / Edward St (Bus Terminal)          7235.0
# 4                     Edward St / Yonge St          7257.0
#
#               End Time                         End Station Name  Bike Id  \
# 0  2019-01-01 00:33:00                 King / Cowan Ave - SMART     1296
# 1  2019-01-01 00:29:00      Wellesley St E / Yonge St (Green P)     2947
# 2  2019-01-01 00:25:00                 Scott St / The Esplanade     2293
# 3  2019-01-01 00:20:00  Bay St / College St (West Side) - SMART      283
# 4  2019-01-01 00:24:00             Dundas St W / St. Patrick St     1799
#
#        User Type  start_date start_time   stop_date stop_time
# 0  Annual Member  01/01/2019      00:08  01/01/2019     00:33
# 1  Annual Member  01/01/2019      00:10  01/01/2019     00:29
# 2  Annual Member  01/01/2019      00:15  01/01/2019     00:25
# 3  Annual Member  01/01/2019      00:16  01/01/2019     00:20
# 4  Annual Member  01/01/2019      00:19  01/01/2019     00:24

# %% [markdown]
# Again I can drop some columns here, the same as 2018 but with the addition of the Bike Id column which I won't be looking into for my analysis.

# %%
df_2019.drop(['Unnamed: 0', 'Trip Id', 'Start Station Id', 'End Station Id', 'Bike Id'], axis=1, inplace=True)

# %% [markdown]
# Let's also modify the names of the values in the user type column to match the other DataFrames.

# %%
df_2019['User Type'] = df_2019['User Type'].replace({'Annual Member': 'Member', 'Casual Member': 'Casual'})

# %% [markdown]
# Finally, I'll rename the columns so that they match the column names from the previous DataFrames.

# %%
df_2019 = df_2019.rename(columns={'Trip Duration': 'trip_duration_seconds', 'Start Time': 'trip_start_time', 'Start Station Name': 'from_station_name', 'End Time': 'trip_stop_time', 'End Station Name': 'to_station_name', 'User Type': 'user_type'})

# %%
df_2019.head(5)
# Out:
#    trip_duration_seconds      trip_start_time  \
# 0                 1547.0  2019-01-01 00:08:00
# 1                 1112.0  2019-01-01 00:10:00
# 2                  589.0  2019-01-01 00:15:00
# 3                  259.0  2019-01-01 00:16:00
# 4                  281.0  2019-01-01 00:19:00
#
#                          from_station_name       trip_stop_time  \
# 0                       Bay St / Albert St  2019-01-01 00:33:00
# 1                 King St W / Tecumseth St  2019-01-01 00:29:00
# 2                   Jarvis St / Carlton St  2019-01-01 00:25:00
# 3  Elizabeth St / Edward St (Bus Terminal)  2019-01-01 00:20:00
# 4                     Edward St / Yonge St  2019-01-01 00:24:00
#
#                            to_station_name user_type  start_date start_time  \
# 0                 King / Cowan Ave - SMART    Member  01/01/2019      00:08
# 1      Wellesley St E / Yonge St (Green P)    Member  01/01/2019      00:10
# 2                 Scott St / The Esplanade    Member  01/01/2019      00:15
# 3  Bay St / College St (West Side) - SMART    Member  01/01/2019      00:16
# 4             Dundas St W / St. Patrick St    Member  01/01/2019      00:19
#
#     stop_date stop_time
# 0  01/01/2019     00:33
# 1  01/01/2019     00:29
# 2  01/01/2019     00:25
# 3  01/01/2019     00:20
# 4  01/01/2019     00:24

# %% [markdown]
# Looks good! but i notice that trip_duration is a float datatype. I'll just quickly change that to an int.

# %%
df_2019['trip_duration_seconds'] = df_2019['trip_duration_seconds'].astype(int)

# %%
df_2019.head(5)
# Out:
#    trip_duration_seconds      trip_start_time  \
# 0                   1547  2019-01-01 00:08:00
# 1                   1112  2019-01-01 00:10:00
# 2                    589  2019-01-01 00:15:00
# 3                    259  2019-01-01 00:16:00
# 4                    281  2019-01-01 00:19:00
#
#                          from_station_name       trip_stop_time  \
# 0                       Bay St / Albert St  2019-01-01 00:33:00
# 1                 King St W / Tecumseth St  2019-01-01 00:29:00
# 2                   Jarvis St / Carlton St  2019-01-01 00:25:00
# 3  Elizabeth St / Edward St (Bus Terminal)  2019-01-01 00:20:00
# 4                     Edward St / Yonge St  2019-01-01 00:24:00
#
#                            to_station_name user_type  start_date start_time  \
# 0                 King / Cowan Ave - SMART    Member  01/01/2019      00:08
# 1      Wellesley St E / Yonge St (Green P)    Member  01/01/2019      00:10
# 2                 Scott St / The Esplanade    Member  01/01/2019      00:15
# 3  Bay St / College St (West Side) - SMART    Member  01/01/2019      00:16
# 4             Dundas St W / St. Patrick St    Member  01/01/2019      00:19
#
#     stop_date stop_time
# 0  01/01/2019     00:33
# 1  01/01/2019     00:29
# 2  01/01/2019     00:25
# 3  01/01/2019     00:20
# 4  01/01/2019     00:24

# %% [markdown]
# Great! Now we can move onto the 2020 data...

# %%
df_2020.head(5)
# Out:
#    Trip  Duration           Start Time            Start Station Name  \
# 0             648  2020-01-01 00:08:00      Madison Ave / Bloor St W
# 1             419  2020-01-01 00:10:00         College St / Huron St
# 2             566  2020-01-01 00:13:00  Parliament St / Aberdeen Ave
# 3            1274  2020-01-01 00:17:00       King St E / Victoria St
# 4             906  2020-01-01 00:19:00         King St E / Jarvis St
#
#               End Time                 End Station Name      User Type  \
# 0  2020-01-01 00:19:00  Yonge St / Alexander St - SMART  Annual Member
# 1  2020-01-01 00:17:00               Yonge St / Wood St  Annual Member
# 2  2020-01-01 00:22:00           Front St E / Cherry St  Annual Member
# 3  2020-01-01 00:38:00      Sherbourne St / Isabella St  Annual Member
# 4  2020-01-01 00:34:00          University Ave / Elm St  Casual Member
#
#    start_date start_time   stop_date stop_time
# 0  01/01/2020      00:08  01/01/2020     00:19
# 1  01/01/2020      00:10  01/01/2020     00:17
# 2  01/01/2020      00:13  01/01/2020     00:22
# 3  01/01/2020      00:17  01/01/2020     00:38
# 4  01/01/2020      00:19  01/01/2020     00:34

# %% [markdown]
# Let's drop the unnecessary columns...

# %%
df_2020.drop(['Unnamed: 0', 'Trip Id', 'Start Station Id', 'End Station Id', 'Bike Id'], axis=1, inplace=True)

# %% [markdown]
# Let's change the User Type values to make sure they match.

# %%
df_2020['User Type'] = df_2020['User Type'].replace({'Annual Member': 'Member', 'Casual Member': 'Casual'})

# %% [markdown]
# Let's rename the columns so that they match as well.

# %%
df_2020 = df_2020.rename(columns={'Trip  Duration': 'trip_duration_seconds', 'Start Time': 'trip_start_time', 'Start Station Name': 'from_station_name', 'End Time': 'trip_stop_time', 'End Station Name': 'to_station_name', 'User Type': 'user_type'})

# %%
df_2020.head(5)
# Out:
#    trip_duration_seconds      trip_start_time             from_station_name  \
# 0                    648  2020-01-01 00:08:00      Madison Ave / Bloor St W
# 1                    419  2020-01-01 00:10:00         College St / Huron St
# 2                    566  2020-01-01 00:13:00  Parliament St / Aberdeen Ave
# 3                   1274  2020-01-01 00:17:00       King St E / Victoria St
# 4                    906  2020-01-01 00:19:00         King St E / Jarvis St
#
#         trip_stop_time                  to_station_name user_type  start_date  \
# 0  2020-01-01 00:19:00  Yonge St / Alexander St - SMART    Member  01/01/2020
# 1  2020-01-01 00:17:00               Yonge St / Wood St    Member  01/01/2020
# 2  2020-01-01 00:22:00           Front St E / Cherry St    Member  01/01/2020
# 3  2020-01-01 00:38:00      Sherbourne St / Isabella St    Member  01/01/2020
# 4  2020-01-01 00:34:00          University Ave / Elm St    Casual  01/01/2020
#
#   start_time   stop_date stop_time
# 0      00:08  01/01/2020     00:19
# 1      00:10  01/01/2020     00:17
# 2      00:13  01/01/2020     00:22
# 3      00:17  01/01/2020     00:38
# 4      00:19  01/01/2020     00:34

# %% [markdown]
# Looks good!

# %% [markdown]
# I don't believe we need the trip_start_time or trip_stop_time in any of the dataframes anymore, as we have them nicely separated into individual date and time columns.

# %%
df_2017.drop(['trip_stop_time', 'trip_start_time'], axis=1, inplace=True)
df_2018.drop(['trip_stop_time', 'trip_start_time'], axis=1, inplace=True)
df_2019.drop(['trip_stop_time', 'trip_start_time'], axis=1, inplace=True)
df_2020.drop(['trip_stop_time', 'trip_start_time'], axis=1, inplace=True)

# %% [markdown]
# Now let's start appending the dataframes together...

# %%
df_2017_2018 = df_2017.append(df_2018)

# %%
df_2017_2018
# Out:
#          trip_duration_seconds                           from_station_name  \
# 0                          223           Wellesley St E / Yonge St Green P
# 1                          279                    Kendal Ave / Bernard Ave
# 2                         1394                Parliament St / Aberdeen Ave
# 3                          826                          College Park South
# 4                          279                       McGill St / Church St
# ...                        ...                                         ...
# 1922950                    379                  Danforth Ave / Coxwell Ave
# 1922951                    306                     Bay St / Wellesley St W
# 1922952                    340                     Phoebe St / Spadina Ave
# 1922953                   1466  Sherbourne St / Carlton St (Allan Gardens)
# 1922954                    333                     Mill St / Parliament St
#
#                          to_station_name user_type  start_date start_time  \
# 0                   Church St  / Wood St    Member  01/01/2017      00:00
# 1                Bathurst Subway Station    Member  01/01/2017      00:00
# 2              College St W / Markham St    Member  01/01/2017      00:05
# 3                King St W / Spadina Ave    Member  01/01/2017      00:07
# 4          University Ave / Gerrard St W    Member  01/01/2017      00:08
# ...                                  ...       ...         ...        ...
# 1922950                 Donlands Station    Member  31/12/2018      23:43
# 1922951          Jarvis St / Isabella St    Member  31/12/2018      23:45
# 1922952     Fort York  Blvd / Capreol Ct    Member  31/12/2018      23:49
# 1922953  Toronto Eaton Centre (Yonge St)    Member  31/12/2018      23:52
# 1922954         Scott St / The Esplanade    Member  31/12/2018      23:58
#
#           stop_date stop_time
# 0        01/01/2017     00:03
# 1        01/01/2017     00:05
# 2        01/01/2017     00:29
# 3        01/01/2017     00:21
# 4        01/01/2017     00:12
# ...             ...       ...
# 1922950  31/12/2018     23:49
# 1922951  31/12/2018     23:50
# 1922952  31/12/2018     23:55
# 1922953  01/01/2019     00:17
# 1922954  01/01/2019     00:04
#
# [3415323 rows x 8 columns]

# %% [markdown]
# Looks good! Now let's append on 2019...

# %%
df_17_18_19 = df_2017_2018.append(df_2019)

# %%
df_17_18_19
# Out:
#          trip_duration_seconds                     from_station_name  \
# 0                          223     Wellesley St E / Yonge St Green P
# 1                          279              Kendal Ave / Bernard Ave
# 2                         1394          Parliament St / Aberdeen Ave
# 3                          826                    College Park South
# 4                          279                 McGill St / Church St
# ...                        ...                                   ...
# 2439042                    523  Riverdale Park South (Broadview Ave)
# 2439043                    273              Church St / Alexander St
# 2439044                   1055        Dundas St E / Regent Park Blvd
# 2439045                    459           York St / Lake Shore Blvd W
# 2439046                    361                Queens Quay / Yonge St
#
#                         to_station_name user_type  start_date start_time  \
# 0                  Church St  / Wood St    Member  01/01/2017      00:00
# 1               Bathurst Subway Station    Member  01/01/2017      00:00
# 2             College St W / Markham St    Member  01/01/2017      00:05
# 3               King St W / Spadina Ave    Member  01/01/2017      00:07
# 4         University Ave / Gerrard St W    Member  01/01/2017      00:08
# ...                                 ...       ...         ...        ...
# 2439042     Carlaw Ave / Strathcona Ave    Member  31/12/2019      23:39
# 2439043     Bay St / Charles St - SMART    Member  31/12/2019      23:45
# 2439044  Dundas St E / Regent Park Blvd    Member  31/12/2019      23:51
# 2439045           Nelson St / Duncan St    Member  31/12/2019      23:55
# 2439046                   Union Station    Member  31/12/2019      23:58
#
#           stop_date stop_time
# 0        01/01/2017     00:03
# 1        01/01/2017     00:05
# 2        01/01/2017     00:29
# 3        01/01/2017     00:21
# 4        01/01/2017     00:12
# ...             ...       ...
# 2439042  31/12/2019     23:48
# 2439043  31/12/2019     23:49
# 2439044  01/01/2020     00:08
# 2439045  01/01/2020     00:03
# 2439046  01/01/2020     00:04
#
# [5854370 rows x 8 columns]

# %% [markdown]
# Looks good! Now let's append on the 2020 data for our final dataframe.

# %%
bikeshare_data = df_17_18_19.append(df_2020)

# %%
bikeshare_data
# Out:
#          trip_duration_seconds                  from_station_name  \
# 0                          223  Wellesley St E / Yonge St Green P
# 1                          279           Kendal Ave / Bernard Ave
# 2                         1394       Parliament St / Aberdeen Ave
# 3                          826                 College Park South
# 4                          279              McGill St / Church St
# ...                        ...                                ...
# 2908162                    330            King St W / Spadina Ave
# 2908163                    216        Humber Bay Shores Park West
# 2908164                    204        Humber Bay Shores Park West
# 2908165                   1659    Church St / Dundas St E - SMART
# 2908166                     63                      12 Harbour St
#
#                                    to_station_name user_type  start_date  \
# 0                             Church St  / Wood St    Member  01/01/2017
# 1                          Bathurst Subway Station    Member  01/01/2017
# 2                        College St W / Markham St    Member  01/01/2017
# 3                          King St W / Spadina Ave    Member  01/01/2017
# 4                    University Ave / Gerrard St W    Member  01/01/2017
# ...                                            ...       ...         ...
# 2908162              Wellington St W / Stafford St    Member  31/12/2020
# 2908163  Humber Bay Shores Park / Marine Parade Dr    Member  31/12/2020
# 2908164  Humber Bay Shores Park / Marine Parade Dr    Member  31/12/2020
# 2908165            Church St / Dundas St E - SMART    Member  31/12/2020
# 2908166                              12 Harbour St    Member  31/12/2020
#
#         start_time   stop_date stop_time
# 0            00:00  01/01/2017     00:03
# 1            00:00  01/01/2017     00:05
# 2            00:05  01/01/2017     00:29
# 3            00:07  01/01/2017     00:21
# 4            00:08  01/01/2017     00:12
# ...            ...         ...       ...
# 2908162      23:52  31/12/2020     23:57
# 2908163      23:54  31/12/2020     23:58
# 2908164      23:54  31/12/2020     23:58
# 2908165      23:56  01/01/2021     00:24
# 2908166      23:57  31/12/2020     23:58
#
# [8762537 rows x 8 columns]

# %% [markdown]
# It looks good other than the index numbers looking off. I'll just reset the index so that they go in order.

# %%
bikeshare_data.reset_index(inplace=True)
bikeshare_data
# Out:
#            index  trip_duration_seconds                  from_station_name  \
# 0              0                    223  Wellesley St E / Yonge St Green P
# 1              1                    279           Kendal Ave / Bernard Ave
# 2              2                   1394       Parliament St / Aberdeen Ave
# 3              3                    826                 College Park South
# 4              4                    279              McGill St / Church St
# ...          ...                    ...                                ...
# 8762532  2908162                    330            King St W / Spadina Ave
# 8762533  2908163                    216        Humber Bay Shores Park West
# 8762534  2908164                    204        Humber Bay Shores Park West
# 8762535  2908165                   1659    Church St / Dundas St E - SMART
# 8762536  2908166                     63                      12 Harbour St
#
#                                    to_station_name user_type  start_date  \
# 0                             Church St  / Wood St    Member  01/01/2017
# 1                          Bathurst Subway Station    Member  01/01/2017
# 2                        College St W / Markham St    Member  01/01/2017
# 3                          King St W / Spadina Ave    Member  01/01/2017
# 4                    University Ave / Gerrard St W    Member  01/01/2017
# ...                                            ...       ...         ...
# 8762532              Wellington St W / Stafford St    Member  31/12/2020
# 8762533  Humber Bay Shores Park / Marine Parade Dr    Member  31/12/2020
# 8762534  Humber Bay Shores Park / Marine Parade Dr    Member  31/12/2020
# 8762535            Church St / Dundas St E - SMART    Member  31/12/2020
# 8762536                              12 Harbour St    Member  31/12/2020
#
#         start_time   stop_date stop_time
# 0            00:00  01/01/2017     00:03
# 1            00:00  01/01/2017     00:05
# 2            00:05  01/01/2017     00:29
# 3            00:07  01/01/2017     00:21
# 4            00:08  01/01/2017     00:12
# ...            ...         ...       ...
# 8762532      23:52  31/12/2020     23:57
# 8762533      23:54  31/12/2020     23:58
# 8762534      23:54  31/12/2020     23:58
# 8762535      23:56  01/01/2021     00:24
# 8762536      23:57  31/12/2020     23:58
#
# [8762537 rows x 9 columns]

# %%
bikeshare_data.drop('index', axis=1, inplace=True)
bikeshare_data
# Out:
#          trip_duration_seconds                  from_station_name  \
# 0                          223  Wellesley St E / Yonge St Green P
# 1                          279           Kendal Ave / Bernard Ave
# 2                         1394       Parliament St / Aberdeen Ave
# 3                          826                 College Park South
# 4                          279              McGill St / Church St
# ...                        ...                                ...
# 8762532                    330            King St W / Spadina Ave
# 8762533                    216        Humber Bay Shores Park West
# 8762534                    204        Humber Bay Shores Park West
# 8762535                   1659    Church St / Dundas St E - SMART
# 8762536                     63                      12 Harbour St
#
#                                    to_station_name user_type  start_date  \
# 0                             Church St  / Wood St    Member  01/01/2017
# 1                          Bathurst Subway Station    Member  01/01/2017
# 2                        College St W / Markham St    Member  01/01/2017
# 3                          King St W / Spadina Ave    Member  01/01/2017
# 4                    University Ave / Gerrard St W    Member  01/01/2017
# ...                                            ...       ...         ...
# 8762532              Wellington St W / Stafford St    Member  31/12/2020
# 8762533  Humber Bay Shores Park / Marine Parade Dr    Member  31/12/2020
# 8762534  Humber Bay Shores Park / Marine Parade Dr    Member  31/12/2020
# 8762535            Church St / Dundas St E - SMART    Member  31/12/2020
# 8762536                              12 Harbour St    Member  31/12/2020
#
#         start_time   stop_date stop_time
# 0            00:00  01/01/2017     00:03
# 1            00:00  01/01/2017     00:05
# 2            00:05  01/01/2017     00:29
# 3            00:07  01/01/2017     00:21
# 4            00:08  01/01/2017     00:12
# ...            ...         ...       ...
# 8762532      23:52  31/12/2020     23:57
# 8762533      23:54  31/12/2020     23:58
# 8762534      23:54  31/12/2020     23:58
# 8762535      23:56  01/01/2021     00:24
# 8762536      23:57  31/12/2020     23:58
#
# [8762537 rows x 8 columns]

# %% [markdown]
# Great, now the data is ready for some visual based analysis in Tableau. I'll finish off by saving this to csv.

# %%
bikeshare_data.to_csv('Desktop/to_bikeshare_project/bikeshare_data.csv')
