# %% [markdown]
# The purpose of this notebook is to aggregate the rideshare data into four dataframes, one for each year. The data from Toronto Open Data has been saved into quarterly csvs for 2017, 2018, and 2019, and monthly csvs for 2020.

# %% [markdown]
# I'll start by importing the necessary packages for dataframe manipulation.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 2017 Data

# %% [markdown]
# I'll read in the four quarters of data with pd.read_csv to four dataframes.

# %%
df_2017_1 = pd.read_csv('Desktop/2017_bikeshare/Bikeshare Ridership (2017 Q1).csv')
df_2017_2 = pd.read_csv('Desktop/2017_bikeshare/Bikeshare Ridership (2017 Q2).csv')
df_2017_3 = pd.read_csv('Desktop/2017_bikeshare/Bikeshare Ridership (2017 Q3).csv')
df_2017_4 = pd.read_csv('Desktop/2017_bikeshare/Bikeshare Ridership (2017 Q4).csv')

# %% [markdown]
# Let's quickly check out what the data looks like.

# %%
df_2017_1.head(5)
# Out:
#    trip_id trip_start_time trip_stop_time  trip_duration_seconds  \
# 0   712382   1/1/2017 0:00  1/1/2017 0:03                    223
# 1   712383   1/1/2017 0:00  1/1/2017 0:05                    279
# 2   712384   1/1/2017 0:05  1/1/2017 0:29                   1394
# 3   712385   1/1/2017 0:07  1/1/2017 0:21                    826
# 4   712386   1/1/2017 0:08  1/1/2017 0:12                    279
#
#    from_station_id                  from_station_name  to_station_id  \
# 0             7051  Wellesley St E / Yonge St Green P           7089
# 1             7143           Kendal Ave / Bernard Ave           7154
# 2             7113       Parliament St / Aberdeen Ave           7199
# 3             7077                 College Park South           7010
# 4             7079              McGill St / Church St           7047
#
#                  to_station_name user_type
# 0           Church St  / Wood St    Member
# 1        Bathurst Subway Station    Member
# 2      College St W / Markham St    Member
# 3        King St W / Spadina Ave    Member
# 4  University Ave / Gerrard St W    Member

# %% [markdown]
# Now let's concatenate the data along axis=0 (downwards) using pandas concat.

# %%
df_2017 = pd.concat([df_2017_1, df_2017_2], axis=0)

# %%
df_2017 = pd.concat([df_2017, df_2017_3], axis=0)

# %%
df_2017 = pd.concat([df_2017, df_2017_4], axis=0)

# %% [markdown]
# Let's check out the full dataframe now.

# %%
df_2017
# Out:
#         trip_id    trip_start_time     trip_stop_time  trip_duration_seconds  \
# 0        712382      1/1/2017 0:00      1/1/2017 0:03                    223
# 1        712383      1/1/2017 0:00      1/1/2017 0:05                    279
# 2        712384      1/1/2017 0:05      1/1/2017 0:29                   1394
# 3        712385      1/1/2017 0:07      1/1/2017 0:21                    826
# 4        712386      1/1/2017 0:08      1/1/2017 0:12                    279
# ...         ...                ...                ...                    ...
# 363400  2383642  12/31/17 23:46:27  12/31/17 23:46:53                     26
# 363401  2383643  12/31/17 23:47:13   1/01/18 00:11:40                   1467
# 363402  2383644  12/31/17 23:47:40  12/31/17 23:57:49                    609
# 363403  2383645  12/31/17 23:49:08  12/31/17 23:49:34                     26
# 363404  2383646  12/31/17 23:49:41  12/31/17 23:57:41                    480
#
#         from_station_id                  from_station_name  to_station_id  \
# 0                7051.0  Wellesley St E / Yonge St Green P         7089.0
# 1                7143.0           Kendal Ave / Bernard Ave         7154.0
# 2                7113.0       Parliament St / Aberdeen Ave         7199.0
# 3                7077.0                 College Park South         7010.0
# 4                7079.0              McGill St / Church St         7047.0
# ...                 ...                                ...            ...
# 363400              NaN           Bloor St / Brunswick Ave            NaN
# 363401              NaN           Bloor St / Brunswick Ave            NaN
# 363402              NaN            Kendal Ave / Spadina Rd            NaN
# 363403              NaN            Phoebe St / Spadina Ave            NaN
# 363404              NaN            Phoebe St / Spadina Ave            NaN
#
#                       to_station_name user_type
# 0                Church St  / Wood St    Member
# 1             Bathurst Subway Station    Member
# 2           College St W / Markham St    Member
# 3             King St W / Spadina Ave    Member
# 4       University Ave / Gerrard St W    Member
# ...                               ...       ...
# 363400       Bloor St / Brunswick Ave    Casual
# 363401       HTO Park (Queens Quay W)    Casual
# 363402       Augusta Ave / Denison Sq    Member
# 363403        Phoebe St / Spadina Ave    Member
# 363404         Simcoe St / Queen St W    Member
#
# [1492369 rows x 9 columns]

# %% [markdown]
# Now the rides from 2017 have been fully concatenated into a single DataFrame. There were 1,492,369 rides in 2017. We have some null values but we can clean this up later.

# %% [markdown]
# Let's save this dataframe to a new csv file.

# %%
df_2017.to_csv('Desktop/df_2017.csv')

# %% [markdown]
# ---------

# %% [markdown]
# # 2018 Data

# %% [markdown]
# Let's read in the quarterly csvs to data frames.

# %%
df_2018_1 = pd.read_csv('Desktop/2018_bikeshare/Bike Share Toronto Ridership_Q1 2018.csv')
df_2018_2 = pd.read_csv('Desktop/2018_bikeshare/Bike Share Toronto Ridership_Q2 2018.csv')
df_2018_3 = pd.read_csv('Desktop/2018_bikeshare/Bike Share Toronto Ridership_Q3 2018.csv')
df_2018_4 = pd.read_csv('Desktop/2018_bikeshare/Bike Share Toronto Ridership_Q4 2018.csv')

# %% [markdown]
# Quickly checking one out....

# %%
df_2018_1.head(5)
# Out:
#    trip_id  trip_duration_seconds  from_station_id trip_start_time  \
# 0  2383648                    393             7018   1/1/2018 0:47
# 1  2383649                    625             7184   1/1/2018 0:52
# 2  2383650                    233             7235   1/1/2018 0:55
# 3  2383651                   1138             7202   1/1/2018 0:57
# 4  2383652                    703             7004   1/1/2018 1:00
#
#                          from_station_name trip_stop_time  to_station_id  \
# 0                   Bremner Blvd / Rees St  1/1/2018 0:54           7176
# 1               Ossington Ave / College St  1/1/2018 1:03           7191
# 2  Bay St / College St (West Side) - SMART  1/1/2018 0:59           7021
# 3         Queen St W / York St (City Hall)  1/1/2018 1:16           7020
# 4                  University Ave / Elm St  1/1/2018 1:12           7060
#
#                 to_station_name      user_type
# 0  Bathurst St / Fort York Blvd  Annual Member
# 1    Central Tech  (Harbord St)  Annual Member
# 2            Bay St / Albert St  Annual Member
# 3       Phoebe St / Spadina Ave  Annual Member
# 4   Princess St / Adelaide St E  Annual Member

# %% [markdown]
# Now the concatenation...

# %%
df_2018 = pd.concat([df_2018_1, df_2018_2], axis=0)

# %%
df_2018 = pd.concat([df_2018, df_2018_3], axis=0)

# %%
df_2018 = pd.concat([df_2018, df_2018_4], axis=0)

# %% [markdown]
# Let's inspect the final DataFrame.

# %%
df_2018
# Out:
#         trip_id  trip_duration_seconds  from_station_id   trip_start_time  \
# 0       2383648                    393             7018     1/1/2018 0:47
# 1       2383649                    625             7184     1/1/2018 0:52
# 2       2383650                    233             7235     1/1/2018 0:55
# 3       2383651                   1138             7202     1/1/2018 0:57
# 4       2383652                    703             7004     1/1/2018 1:00
# ...         ...                    ...              ...               ...
# 363485  4581273                    379             7088  12/31/2018 23:43
# 363486  4581274                    306             7030  12/31/2018 23:45
# 363487  4581275                    340             7020  12/31/2018 23:49
# 363488  4581276                   1466             7014  12/31/2018 23:52
# 363489  4581277                    333             7299  12/31/2018 23:58
#
#                                  from_station_name    trip_stop_time  \
# 0                           Bremner Blvd / Rees St     1/1/2018 0:54
# 1                       Ossington Ave / College St     1/1/2018 1:03
# 2          Bay St / College St (West Side) - SMART     1/1/2018 0:59
# 3                 Queen St W / York St (City Hall)     1/1/2018 1:16
# 4                          University Ave / Elm St     1/1/2018 1:12
# ...                                            ...               ...
# 363485                  Danforth Ave / Coxwell Ave  12/31/2018 23:49
# 363486                     Bay St / Wellesley St W  12/31/2018 23:50
# 363487                     Phoebe St / Spadina Ave  12/31/2018 23:55
# 363488  Sherbourne St / Carlton St (Allan Gardens)     1/1/2019 0:17
# 363489                     Mill St / Parliament St     1/1/2019 0:04
#
#         to_station_id                  to_station_name      user_type
# 0                7176     Bathurst St / Fort York Blvd  Annual Member
# 1                7191       Central Tech  (Harbord St)  Annual Member
# 2                7021               Bay St / Albert St  Annual Member
# 3                7020          Phoebe St / Spadina Ave  Annual Member
# 4                7060      Princess St / Adelaide St E  Annual Member
# ...               ...                              ...            ...
# 363485           7091                 Donlands Station  Annual Member
# 363486           7031          Jarvis St / Isabella St  Annual Member
# 363487           7000     Fort York  Blvd / Capreol Ct  Annual Member
# 363488           7269  Toronto Eaton Centre (Yonge St)  Annual Member
# 363489           7013         Scott St / The Esplanade  Annual Member
#
# [1922955 rows x 9 columns]

# %% [markdown]
# Now the data from 2018 has been fully concatenated. There were 1,922,955 rides in 2018.

# %%
# saving to csv
df_2018.to_csv('Desktop/df_2018.csv')

# %% [markdown]
# ------------------------

# %% [markdown]
# # 2019 Data

# %%
# again reading in the csv files
df_2019_1 = pd.read_csv('Desktop/2019_bikeshare/2019-Q1.csv')
df_2019_2 = pd.read_csv('Desktop/2019_bikeshare/2019-Q2.csv')
df_2019_3 = pd.read_csv('Desktop/2019_bikeshare/2019-Q3.csv')
df_2019_4 = pd.read_csv('Desktop/2019_bikeshare/2019-Q4.csv')

# %%
# checking out one of the dataframes
df_2019_1.head(5)
# Out:
#    Trip Id  Trip  Duration  Start Station Id        Start Time  \
# 0  4581278          1547.0              7021  01/01/2019 00:08
# 1  4581279          1112.0              7160  01/01/2019 00:10
# 2  4581280           589.0              7055  01/01/2019 00:15
# 3  4581281           259.0              7012  01/01/2019 00:16
# 4  4581282           281.0              7041  01/01/2019 00:19
#
#                         Start Station Name  End Station Id          End Time  \
# 0                       Bay St / Albert St            7233  01/01/2019 00:33
# 1                 King St W / Tecumseth St            7051  01/01/2019 00:29
# 2                   Jarvis St / Carlton St            7013  01/01/2019 00:25
# 3  Elizabeth St / Edward St (Bus Terminal)            7235  01/01/2019 00:20
# 4                     Edward St / Yonge St            7257  01/01/2019 00:24
#
#                           End Station Name  Bike Id      User Type
# 0                 King / Cowan Ave - SMART     1296  Annual Member
# 1      Wellesley St E / Yonge St (Green P)     2947  Annual Member
# 2                 Scott St / The Esplanade     2293  Annual Member
# 3  Bay St / College St (West Side) - SMART      283  Annual Member
# 4             Dundas St W / St. Patrick St     1799  Annual Member

# %% [markdown]
# Concatenating the same as with the previous DataFrames...

# %%
df_2019 = pd.concat([df_2019_1, df_2019_2], axis=0)

# %%
df_2019 = pd.concat([df_2019, df_2019_3], axis=0)

# %%
df_2019 = pd.concat([df_2019, df_2019_4], axis=0)

# %%
# Inspecting the final DataFrame....
df_2019
# Out:
#         Trip Id  Trip  Duration  Start Station Id        Start Time  \
# 0       4581278          1547.0              7021  01/01/2019 00:08
# 1       4581279          1112.0              7160  01/01/2019 00:10
# 2       4581280           589.0              7055  01/01/2019 00:15
# 3       4581281           259.0              7012  01/01/2019 00:16
# 4       4581282           281.0              7041  01/01/2019 00:19
# ...         ...             ...               ...               ...
# 468411  7334123           523.0              7098  12/31/2019 23:39
# 468412  7334124           273.0              7044  12/31/2019 23:45
# 468413  7334125          1055.0              7100  12/31/2019 23:51
# 468414  7334126           459.0              7470  12/31/2019 23:55
# 468415  7334127           361.0              7168  12/31/2019 23:58
#
#                              Start Station Name  End Station Id  \
# 0                            Bay St / Albert St          7233.0
# 1                      King St W / Tecumseth St          7051.0
# 2                        Jarvis St / Carlton St          7013.0
# 3       Elizabeth St / Edward St (Bus Terminal)          7235.0
# 4                          Edward St / Yonge St          7257.0
# ...                                         ...             ...
# 468411     Riverdale Park South (Broadview Ave)          7339.0
# 468412                 Church St / Alexander St          7273.0
# 468413           Dundas St E / Regent Park Blvd          7100.0
# 468414              York St / Lake Shore Blvd W          7102.0
# 468415                   Queens Quay / Yonge St          7033.0
#
#                 End Time                         End Station Name  Bike Id  \
# 0       01/01/2019 00:33                 King / Cowan Ave - SMART     1296
# 1       01/01/2019 00:29      Wellesley St E / Yonge St (Green P)     2947
# 2       01/01/2019 00:25                 Scott St / The Esplanade     2293
# 3       01/01/2019 00:20  Bay St / College St (West Side) - SMART      283
# 4       01/01/2019 00:24             Dundas St W / St. Patrick St     1799
# ...                  ...                                      ...      ...
# 468411  12/31/2019 23:48              Carlaw Ave / Strathcona Ave      861
# 468412  12/31/2019 23:49              Bay St / Charles St - SMART     3776
# 468413  01/01/2020 00:08           Dundas St E / Regent Park Blvd     2382
# 468414  01/01/2020 00:03                    Nelson St / Duncan St     2800
# 468415  01/01/2020 00:04                            Union Station     4139
#
#             User Type
# 0       Annual Member
# 1       Annual Member
# 2       Annual Member
# 3       Annual Member
# 4       Annual Member
# ...               ...
# 468411  Annual Member
# 468412  Annual Member
# 468413  Annual Member
# 468414  Annual Member
# 468415  Annual Member
#
# [2439517 rows x 10 columns]

# %% [markdown]
# 2,439,517 trips in 2019. Cool! Now I'll save to csv...

# %%
df_2019.to_csv('Desktop/df_2019.csv')

# %% [markdown]
# ----------------

# %% [markdown]
# # 2020 Data

# %% [markdown]
# For the 2020 data it was saved into monthly csvs, so I'll have to read in more files this time.

# %%
df_2020_1 = pd.read_csv('Desktop/2020_bikeshare/2020-01.csv')
df_2020_2 = pd.read_csv('Desktop/2020_bikeshare/2020-02.csv')
df_2020_3 = pd.read_csv('Desktop/2020_bikeshare/2020-03.csv')
df_2020_4 = pd.read_csv('Desktop/2020_bikeshare/2020-04.csv')
df_2020_5 = pd.read_csv('Desktop/2020_bikeshare/2020-05.csv')
df_2020_6 = pd.read_csv('Desktop/2020_bikeshare/2020-06.csv')
df_2020_7 = pd.read_csv('Desktop/2020_bikeshare/2020-07.csv')
df_2020_8 = pd.read_csv('Desktop/2020_bikeshare/2020-08.csv')
df_2020_9 = pd.read_csv('Desktop/2020_bikeshare/2020-09.csv')
df_2020_10 = pd.read_csv('Desktop/2020_bikeshare/2020-10.csv')
df_2020_11 = pd.read_csv('Desktop/2020_bikeshare/2020-11.csv')
df_2020_12 = pd.read_csv('Desktop/2020_bikeshare/2020-12.csv')

# %% [markdown]
# And now concatenating....

# %%
df_2020 = pd.concat([df_2020_1, df_2020_2], axis=0)

# %%
df_2020 = pd.concat([df_2020, df_2020_3], axis=0)

# %%
df_2020 = pd.concat([df_2020, df_2020_4], axis=0)

# %%
df_2020 = pd.concat([df_2020, df_2020_5], axis=0)

# %%
df_2020 = pd.concat([df_2020, df_2020_6], axis=0)

# %%
df_2020 = pd.concat([df_2020, df_2020_7], axis=0)

# %%
df_2020 = pd.concat([df_2020, df_2020_8], axis=0)

# %%
df_2020 = pd.concat([df_2020, df_2020_9], axis=0)

# %%
df_2020 = pd.concat([df_2020, df_2020_10], axis=0)

# %%
df_2020 = pd.concat([df_2020, df_2020_11], axis=0)

# %%
df_2020 = pd.concat([df_2020, df_2020_12], axis=0)

# %% [markdown]
# Let's check out the final DataFrame.

# %%
df_2020
# Out:
#         Trip Id  Trip  Duration Start Station Id        Start Time  \
# 0       7334128             648             7003  01/01/2020 00:08
# 1       7334129             419             7007  01/01/2020 00:10
# 2       7334130             566             7113  01/01/2020 00:13
# 3       7334131            1274             7333  01/01/2020 00:17
# 4       7334132             906             7009  01/01/2020 00:19
# ...         ...             ...              ...               ...
# 95343  10644213             330             7010  12/31/2020 23:52
# 95344  10644214             216             7288  12/31/2020 23:54
# 95345  10644215             204             7288  12/31/2020 23:54
# 95346  10644216            1659             7270  12/31/2020 23:56
# 95347  10644217              63             7383  12/31/2020 23:57
#
#                     Start Station Name End Station Id          End Time  \
# 0             Madison Ave / Bloor St W         7271.0  01/01/2020 00:19
# 1                College St / Huron St         7163.0  01/01/2020 00:17
# 2         Parliament St / Aberdeen Ave         7108.0  01/01/2020 00:22
# 3              King St E / Victoria St         7311.0  01/01/2020 00:38
# 4                King St E / Jarvis St         7004.0  01/01/2020 00:34
# ...                                ...            ...               ...
# 95343          King St W / Spadina Ave         7216.0  12/31/2020 23:57
# 95344      Humber Bay Shores Park West         7514.0  12/31/2020 23:58
# 95345      Humber Bay Shores Park West         7514.0  12/31/2020 23:58
# 95346  Church St / Dundas St E - SMART         7270.0  01/01/2021 00:24
# 95347                    12 Harbour St         7383.0  12/31/2020 23:58
#
#                                 End Station Name Bike Id      User Type
# 0                Yonge St / Alexander St - SMART    3104  Annual Member
# 1                             Yonge St / Wood St    2126  Annual Member
# 2                         Front St E / Cherry St    4425  Annual Member
# 3                    Sherbourne St / Isabella St    4233  Annual Member
# 4                        University Ave / Elm St    2341  Casual Member
# ...                                          ...     ...            ...
# 95343              Wellington St W / Stafford St  3458.0  Annual Member
# 95344  Humber Bay Shores Park / Marine Parade Dr  4085.0  Annual Member
# 95345  Humber Bay Shores Park / Marine Parade Dr  3580.0  Annual Member
# 95346            Church St / Dundas St E - SMART  5137.0  Annual Member
# 95347                              12 Harbour St  5622.0  Annual Member
#
# [2911308 rows x 10 columns]

# %% [markdown]
# The data from 2020 is now fully concatenated. There were 2,911,308 rides in 2020!

# %% [markdown]
# Let's save this 2020 DataFrame.

# %%
df_2020.to_csv('Desktop/df_2020.csv')

# %% [markdown]
# --------------
